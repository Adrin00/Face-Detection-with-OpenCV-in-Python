# %% [markdown]
# CV- Computer  Vision

# %% [markdown]
# #installation process

# %%
# !pip install opencv-python

# %% [markdown]
# #import OpenCV library

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %% [markdown]
# #Steps:
# 1. input images
# 2. extract RGB values of each pixel
# 3. Resize the images
# 4. Image Recognition/detection algorithms
# 5. Adding artifacts that help with the above step
# 6. Displaying the result.

# %% [markdown]
# #Functions
# 1.  cv2.imread() - used to input an image to work with
# 2.  cv2.imshow() - displays the image in the working environment
# 3.  cv2.imwrite() - write any changes in to an actual image

# %% [markdown]
# #cv2.imread()
# 1. syntax: cv2.imread(file path, flag)
# 2. file path: denotes location of the image to be read.
# 3. flag: specifies the way in which to read the image (color- 3 channels(RGB), grayscale- 1 channel(Black and White) etc)
# 4. return: returns an image that is loaded from the specified location.

# %% [markdown]
# #cv2.imshow()
# 1. syntax: cv2.imshow(windowname, image to be displayed)
# 2. Window name: name of the window in which to dispaly the file in.
# 3. return: no return value to program but displays the image on the screen.

# %% [markdown]
# ##cv2.imwrite()
# 1. syntax: cv2.imwrite(filename, image to be saved)
# 2. file name:name of the file that will be saved (Needs file extension).
# 3. return: returns a Boolean True if the image was saved successfully.

# %% [markdown]
# #What is face detection?
# #How can computers detect objects in images?
# 1. Commonalities between all of the faces in terms of features help.
# 2. Face detection algorithms like Viola-Jones algorithm is very popular.
# 3. Similar concepts can be applied for detection of faces for other applications.

# %% [markdown]
# #What is face detection?
# #Face detection is key!
# Face detection is the first step towards any face-related technology like face detection or recognition.Proprietary content.

# %% [markdown]
# #What is face recognition?
# #Face recognition is one of the most used applications of OpenCV.
# 1. Face recognition is a method of verifying the identity of a person using their face.
# 2. Deep learning is super popular for face recognition applications.
# 3. Face recognition is used across hundredsof applications.

# %% [markdown]
# #How is face recognition achieved?
# Face recognition can be achieved using many sources:
# 1. Images from a dataset
# 2. Live webcamfeed
# 3. Recorded videos etc.

# %% [markdown]
# #Applications of face recognition
# #Numerous applications:
# 1. Locking mechanism for your devices
# 2. Prevention of retail crime
# 3. Finding missing people
# 4. Identify people on social media platform
# 5. Helping ease the travel load on airports
# 6. Aiding forensic investigations
# 7. Track school attendance●Identity validation at ATMs

# %% [markdown]
# #Face recognition using Deep Learning
# #Dataset for training
# 1. Training a complex network required here will take a significant amount of data and computation power.
# 2. A pre-trained network trained by Davis King on a dataset of ~3 million images is used to speed up the process.
# 3. The network outputs a vector of 128 numbers which represent the most important features of a face

# %% [markdown]
# #Face recognition using Deep Learning
# #Step 1: Face detection
# The exact location/coordinatesof face is extracted from media.
# #Step 2: Feature Extraction
# Face embedding is used with each face to convert it into a vectorand this technique is called Deep Metric Learning.Proprietary content.
# #Step 3: Training a neural network
# A neural network may output faces which look very similar to each other. What is the solution here.
#
# #Step 4: Feature map across the face
# After training the network, it understands to group similar looking facestogether into one category
#
# #Step 5: Embeddings for images are obtained after training
# 1. The first step is to computethe face embedding for the image using the same network.
# 2. Embeddings of Putin were notsavedwhile the embeddings of George Bush was

# %% [markdown]
# #Face Detection with Python using OpenCV
# #coding part

# %%
#Import the OpenCV library
import cv2

# %%
#Using the pre-trained classifier from OpenCV
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')#Load the cascade

# %%
#Upload the input image
img = cv2.imread('obama.jpg')

# %%
#Perform face detection
faces = face_cascade.detectMultiScale(img, 1.1, 4) #Detect faces

# %%
#Drawing rectangle around the faces
for (x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
#Exporting the image file
cv2.imwrite("face_detected.jpg", img)
print('Photo successfully exported!')
# Out:
# Photo successfully exported!

# %%
from google.colab.patches import cv2_imshow
import cv2

img= cv2.imread('/content/obama.jpg')
img
# Out:
# array([[[  2,   0,   1],
#         [  3,   0,   2],
#         [  6,   3,   5],
#         ...,
#         [ 83,  91,  91],
#         [ 83,  91,  91],
#         [ 83,  91,  91]],
#
#        [[  2,   0,   1],
#         [  3,   0,   2],
#         [  6,   3,   5],
#         ...,
#         [ 83,  91,  91],
#         [ 83,  91,  91],
#         [ 83,  91,  91]],
#
#        [[  2,   0,   0],
#         [  5,   3,   3],
#         [  7,   5,   5],
#         ...,
#         [ 83,  91,  91],
#         [ 83,  91,  91],
#         [ 83,  91,  91]],
#
#        ...,
#
#        [[ 91,  97, 102],
#         [ 93,  99, 104],
#         [ 96, 102, 107],
#         ...,
#         [116, 119, 123],
#         [108, 112, 117],
#         [114, 118, 123]],
#
#        [[ 91,  97, 102],
#         [ 93,  99, 104],
#         [ 96, 102, 107],
#         ...,
#         [112, 115, 119],
#         [103, 107, 112],
#         [109, 113, 118]],
#
#        [[ 90,  96, 101],
#         [ 92,  98, 103],
#         [ 96, 102, 107],
# ...

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# -1

# %%
img= cv2.imread('/content/obama.jpg',0)
cv2_imshow(img)
cv2.waitKey()
img.shape
# Out:
# <PIL.Image.Image image mode=L size=300x168>
# (168, 300)

# %%
img= cv2.imread('/content/obama.jpg',1)
cv2_imshow(img)
cv2.waitKey()
img.shape
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
# (168, 300, 3)
